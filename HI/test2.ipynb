# %%
import numpy as np
import healpy as hp
import pymaster as nmt
from scipy import optimize
from scipy.linalg import det
import matplotlib.pyplot as plt
import sys
sys.path.append('../')

from scripts.compute_covariance import compute_covariance

# %%
nside=256
freqs=np.arange(544,1088,step=1)
# nfreqs=len(freqs)
nfreqs=181
lmax=2*nside #3*nside -1
almsize=hp.Alm.getsize(lmax)
r=3 #foreground model rank
# n_bins=10

# %%
ff=np.load("/home/iloveorcas/MASS_Thesis/results/ff_maps.npy")[:181]
sync=np.load("/home/iloveorcas/MASS_Thesis/results/sync_maps.npy")[:181]
# hi_maps= np.load("/home/iloveorcas/MASS_Thesis/results/hi_maps.npy")[:181]
noise_maps= np.load("/home/iloveorcas/MASS_Thesis/results/noise_nf.npy")

# %%
noise_maps_1=noise_maps[:181]*1e4 # take only first chunk

# %%
sync.shape
# Out:
# (181, 786432)

# %%
fgds=sync/1e12 +ff
# signal=fgds + hi_maps
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
cl_noise= compute_covariance(noise_maps_1, lmax, almsize, nfreqs)
cl_fgds= compute_covariance(fgds, lmax, almsize, nfreqs)
# cl_hi=compute_covariance(hi_maps, lmax, almsize, nfreqs)
# Out:
# Converting maps 0
# Converting maps 1
# Converting maps 2
# Converting maps 3
# Converting maps 4
# Converting maps 5
# Converting maps 6
# Converting maps 7
# Converting maps 8
# Converting maps 9
# Converting maps 10
# Converting maps 11
# Converting maps 12
# Converting maps 13
# Converting maps 14
# Converting maps 15
# Converting maps 16
# Converting maps 17
# Converting maps 18
# Converting maps 19
# Converting maps 20
# Converting maps 21
# Converting maps 22
# Converting maps 23
# Converting maps 24
# Converting maps 25
# Converting maps 26
# Converting maps 27
# Converting maps 28
# Converting maps 29
# Converting maps 30
# Converting maps 31
# Converting maps 32
# Converting maps 33
# Converting maps 34
# Converting maps 35
# Converting maps 36
# Converting maps 37
# Converting maps 38
# Converting maps 39
# Converting maps 40
# Converting maps 41
# Converting maps 42
# Converting maps 43
# Converting maps 44
# Converting maps 45
# Converting maps 46
# Converting maps 47
# Converting maps 48
# Converting maps 49
# Converting maps 50
# Converting maps 51
# Converting maps 52
# Converting maps 53
# Converting maps 54
# Converting maps 55
# Converting maps 56
# Converting maps 57
# Converting maps 58
# Converting maps 59
# Converting maps 60
# Converting maps 61
# Converting maps 62
# Converting maps 63
# Converting maps 64
# Converting maps 65
# Converting maps 66
# Converting maps 67
# Converting maps 68
# Converting maps 69
# Converting maps 70
# Converting maps 71
# Converting maps 72
# Converting maps 73
# Converting maps 74
# Converting maps 75
# Converting maps 76
# Converting maps 77
# Converting maps 78
# Converting maps 79
# Converting maps 80
# Converting maps 81
# Converting maps 82
# Converting maps 83
# Converting maps 84
# Converting maps 85
# Converting maps 86
# Converting maps 87
# Converting maps 88
# Converting maps 89
# Converting maps 90
# Converting maps 91
# Converting maps 92
# Converting maps 93
# Converting maps 94
# Converting maps 95
# Converting maps 96
# Converting maps 97
# Converting maps 98
# Converting maps 99
# Converting maps 100
# Converting maps 101
# Converting maps 102
# Converting maps 103
# Converting maps 104
# Converting maps 105
# Converting maps 106
# Converting maps 107
# Converting maps 108
# Converting maps 109
# Converting maps 110
# Converting maps 111
# Converting maps 112
# Converting maps 113
# Converting maps 114
# Converting maps 115
# Converting maps 116
# Converting maps 117
# Converting maps 118
# Converting maps 119
# Converting maps 120
# Converting maps 121
# Converting maps 122
# Converting maps 123
# Converting maps 124
# Converting maps 125
# Converting maps 126
# Converting maps 127
# Converting maps 128
# Converting maps 129
# Converting maps 130
# Converting maps 131
# Converting maps 132
# Converting maps 133
# Converting maps 134
# Converting maps 135
# Converting maps 136
# Converting maps 137
# Converting maps 138
# Converting maps 139
# Converting maps 140
# Converting maps 141
# Converting maps 142
# Converting maps 143
# Converting maps 144
# Converting maps 145
# Converting maps 146
# Converting maps 147
# Converting maps 148
# Converting maps 149
# Converting maps 150
# Converting maps 151
# Converting maps 152
# Converting maps 153
# Converting maps 154
# Converting maps 155
# Converting maps 156
# Converting maps 157
# Converting maps 158
# Converting maps 159
# Converting maps 160
# Converting maps 161
# Converting maps 162
# Converting maps 163
# Converting maps 164
# Converting maps 165
# Converting maps 166
# Converting maps 167
# Converting maps 168
# Converting maps 169
# Converting maps 170
# Converting maps 171
# Converting maps 172
# Converting maps 173
# Converting maps 174
# Converting maps 175
# Converting maps 176
# Converting maps 177
# Converting maps 178
# Converting maps 179
# Converting maps 180
# Computing power spectra 0
# Computing power spectra 1
# Computing power spectra 2
# Computing power spectra 3
# Computing power spectra 4
# Computing power spectra 5
# Computing power spectra 6
# Computing power spectra 7
# Computing power spectra 8
# Computing power spectra 9
# Computing power spectra 10
# Computing power spectra 11
# Computing power spectra 12
# Computing power spectra 13
# Computing power spectra 14
# Computing power spectra 15
# Computing power spectra 16
# Computing power spectra 17
# Computing power spectra 18
# Computing power spectra 19
# Computing power spectra 20
# Computing power spectra 21
# Computing power spectra 22
# Computing power spectra 23
# Computing power spectra 24
# Computing power spectra 25
# Computing power spectra 26
# Computing power spectra 27
# Computing power spectra 28
# Computing power spectra 29
# Computing power spectra 30
# Computing power spectra 31
# Computing power spectra 32
# Computing power spectra 33
# Computing power spectra 34
# Computing power spectra 35
# Computing power spectra 36
# Computing power spectra 37
# Computing power spectra 38
# Computing power spectra 39
# Computing power spectra 40
# Computing power spectra 41
# Computing power spectra 42
# Computing power spectra 43
# Computing power spectra 44
# Computing power spectra 45
# Computing power spectra 46
# Computing power spectra 47
# Computing power spectra 48
# Computing power spectra 49
# Computing power spectra 50
# Computing power spectra 51
# Computing power spectra 52
# Computing power spectra 53
# Computing power spectra 54
# Computing power spectra 55
# Computing power spectra 56
# Computing power spectra 57
# Computing power spectra 58
# Computing power spectra 59
# Computing power spectra 60
# Computing power spectra 61
# Computing power spectra 62
# Computing power spectra 63
# Computing power spectra 64
# Computing power spectra 65
# Computing power spectra 66
# Computing power spectra 67
# Computing power spectra 68
# Computing power spectra 69
# Computing power spectra 70
# Computing power spectra 71
# Computing power spectra 72
# Computing power spectra 73
# Computing power spectra 74
# Computing power spectra 75
# Computing power spectra 76
# Computing power spectra 77
# Computing power spectra 78
# Computing power spectra 79
# Computing power spectra 80
# Computing power spectra 81
# Computing power spectra 82
# Computing power spectra 83
# Computing power spectra 84
# Computing power spectra 85
# Computing power spectra 86
# Computing power spectra 87
# Computing power spectra 88
# Computing power spectra 89
# Computing power spectra 90
# Computing power spectra 91
# Computing power spectra 92
# Computing power spectra 93
# Computing power spectra 94
# Computing power spectra 95
# Computing power spectra 96
# Computing power spectra 97
# Computing power spectra 98
# Computing power spectra 99
# Computing power spectra 100
# Computing power spectra 101
# Computing power spectra 102
# Computing power spectra 103
# Computing power spectra 104
# Computing power spectra 105
# Computing power spectra 106
# Computing power spectra 107
# Computing power spectra 108
# Computing power spectra 109
# Computing power spectra 110
# Computing power spectra 111
# Computing power spectra 112
# Computing power spectra 113
# Computing power spectra 114
# Computing power spectra 115
# Computing power spectra 116
# Computing power spectra 117
# Computing power spectra 118
# Computing power spectra 119
# Computing power spectra 120
# Computing power spectra 121
# Computing power spectra 122
# Computing power spectra 123
# Computing power spectra 124
# Computing power spectra 125
# Computing power spectra 126
# Computing power spectra 127
# Computing power spectra 128
# Computing power spectra 129
# Computing power spectra 130
# Computing power spectra 131
# Computing power spectra 132
# Computing power spectra 133
# Computing power spectra 134
# Computing power spectra 135
# Computing power spectra 136
# Computing power spectra 137
# Computing power spectra 138
# Computing power spectra 139
# Computing power spectra 140
# Computing power spectra 141
# Computing power spectra 142
# Computing power spectra 143
# Computing power spectra 144
# Computing power spectra 145
# Computing power spectra 146
# Computing power spectra 147
# Computing power spectra 148
# Computing power spectra 149
# Computing power spectra 150
# Computing power spectra 151
# Computing power spectra 152
# Computing power spectra 153
# Computing power spectra 154
# Computing power spectra 155
# Computing power spectra 156
# Computing power spectra 157
# Computing power spectra 158
# Computing power spectra 159
# Computing power spectra 160
# Computing power spectra 161
# Computing power spectra 162
# Computing power spectra 163
# Computing power spectra 164
# Computing power spectra 165
# Computing power spectra 166
# Computing power spectra 167
# Computing power spectra 168
# Computing power spectra 169
# Computing power spectra 170
# Computing power spectra 171
# Computing power spectra 172
# Computing power spectra 173
# Computing power spectra 174
# Computing power spectra 175
# Computing power spectra 176
# Computing power spectra 177
# Computing power spectra 178
# Computing power spectra 179
# Computing power spectra 180
# Computing power spectra 181
# Computing power spectra 182
# Computing power spectra 183
# Computing power spectra 184
# Computing power spectra 185
# Computing power spectra 186
# Computing power spectra 187
# Computing power spectra 188
# Computing power spectra 189
# Computing power spectra 190
# Computing power spectra 191
# Computing power spectra 192
# Computing power spectra 193
# Computing power spectra 194
# Computing power spectra 195
# Computing power spectra 196
# Computing power spectra 197
# Computing power spectra 198
# Computing power spectra 199
# Computing power spectra 200
# Computing power spectra 201
# Computing power spectra 202
# Computing power spectra 203
# Computing power spectra 204
# Computing power spectra 205
# Computing power spectra 206
# Computing power spectra 207
# Computing power spectra 208
# Computing power spectra 209
# Computing power spectra 210
# Computing power spectra 211
# Computing power spectra 212
# Computing power spectra 213
# Computing power spectra 214
# Computing power spectra 215
# Computing power spectra 216
# Computing power spectra 217
# Computing power spectra 218
# Computing power spectra 219
# Computing power spectra 220
# Computing power spectra 221
# Computing power spectra 222
# Computing power spectra 223
# Computing power spectra 224
# Computing power spectra 225
# Computing power spectra 226
# Computing power spectra 227
# Computing power spectra 228
# Computing power spectra 229
# Computing power spectra 230
# Computing power spectra 231
# Computing power spectra 232
# Computing power spectra 233
# Computing power spectra 234
# Computing power spectra 235
# Computing power spectra 236
# Computing power spectra 237
# Computing power spectra 238
# Computing power spectra 239
# Computing power spectra 240
# Computing power spectra 241
# Computing power spectra 242
# Computing power spectra 243
# Computing power spectra 244
# Computing power spectra 245
# Computing power spectra 246
# Computing power spectra 247
# Computing power spectra 248
# Computing power spectra 249
# Computing power spectra 250
# Computing power spectra 251
# Computing power spectra 252
# Computing power spectra 253
# Computing power spectra 254
# Computing power spectra 255
# Computing power spectra 256
# Computing power spectra 257
# Computing power spectra 258
# Computing power spectra 259
# Computing power spectra 260
# Computing power spectra 261
# Computing power spectra 262
# Computing power spectra 263
# Computing power spectra 264
# Computing power spectra 265
# Computing power spectra 266
# Computing power spectra 267
# Computing power spectra 268
# Computing power spectra 269
# Computing power spectra 270
# Computing power spectra 271
# Computing power spectra 272
# Computing power spectra 273
# Computing power spectra 274
# Computing power spectra 275
# Computing power spectra 276
# Computing power spectra 277
# Computing power spectra 278
# Computing power spectra 279
# Computing power spectra 280
# Computing power spectra 281
# Computing power spectra 282
# Computing power spectra 283
# Computing power spectra 284
# Computing power spectra 285
# Computing power spectra 286
# Computing power spectra 287
# Computing power spectra 288
# Computing power spectra 289
# Computing power spectra 290
# Computing power spectra 291
# Computing power spectra 292
# Computing power spectra 293
# Computing power spectra 294
# Computing power spectra 295
# Computing power spectra 296
# Computing power spectra 297
# Computing power spectra 298
# Computing power spectra 299
# Computing power spectra 300
# Computing power spectra 301
# Computing power spectra 302
# Computing power spectra 303
# Computing power spectra 304
# Computing power spectra 305
# Computing power spectra 306
# Computing power spectra 307
# Computing power spectra 308
# Computing power spectra 309
# Computing power spectra 310
# Computing power spectra 311
# Computing power spectra 312
# Computing power spectra 313
# Computing power spectra 314
# Computing power spectra 315
# Computing power spectra 316
# Computing power spectra 317
# Computing power spectra 318
# Computing power spectra 319
# Computing power spectra 320
# Computing power spectra 321
# Computing power spectra 322
# Computing power spectra 323
# Computing power spectra 324
# Computing power spectra 325
# Computing power spectra 326
# Computing power spectra 327
# Computing power spectra 328
# Computing power spectra 329
# Computing power spectra 330
# Computing power spectra 331
# Computing power spectra 332
# Computing power spectra 333
# Computing power spectra 334
# Computing power spectra 335
# Computing power spectra 336
# Computing power spectra 337
# Computing power spectra 338
# Computing power spectra 339
# Computing power spectra 340
# Computing power spectra 341
# Computing power spectra 342
# Computing power spectra 343
# Computing power spectra 344
# Computing power spectra 345
# Computing power spectra 346
# Computing power spectra 347
# Computing power spectra 348
# Computing power spectra 349
# Computing power spectra 350
# Computing power spectra 351
# Computing power spectra 352
# Computing power spectra 353
# Computing power spectra 354
# Computing power spectra 355
# Computing power spectra 356
# Computing power spectra 357
# Computing power spectra 358
# Computing power spectra 359
# Computing power spectra 360
# Computing power spectra 361
# Computing power spectra 362
# Computing power spectra 363
# Computing power spectra 364
# Computing power spectra 365
# Computing power spectra 366
# Computing power spectra 367
# Computing power spectra 368
# Computing power spectra 369
# Computing power spectra 370
# Computing power spectra 371
# Computing power spectra 372
# Computing power spectra 373
# Computing power spectra 374
# Computing power spectra 375
# Computing power spectra 376
# Computing power spectra 377
# Computing power spectra 378
# Computing power spectra 379
# Computing power spectra 380
# Computing power spectra 381
# Computing power spectra 382
# Computing power spectra 383
# Computing power spectra 384
# Computing power spectra 385
# Computing power spectra 386
# Computing power spectra 387
# Computing power spectra 388
# Computing power spectra 389
# Computing power spectra 390
# Computing power spectra 391
# Computing power spectra 392
# Computing power spectra 393
# Computing power spectra 394
# Computing power spectra 395
# Computing power spectra 396
# Computing power spectra 397
# Computing power spectra 398
# Computing power spectra 399
# Computing power spectra 400
# Computing power spectra 401
# Computing power spectra 402
# Computing power spectra 403
# Computing power spectra 404
# Computing power spectra 405
# Computing power spectra 406
# Computing power spectra 407
# Computing power spectra 408
# Computing power spectra 409
# Computing power spectra 410
# Computing power spectra 411
# Computing power spectra 412
# Computing power spectra 413
# Computing power spectra 414
# Computing power spectra 415
# Computing power spectra 416
# Computing power spectra 417
# Computing power spectra 418
# Computing power spectra 419
# Computing power spectra 420
# Computing power spectra 421
# Computing power spectra 422
# Computing power spectra 423
# Computing power spectra 424
# Computing power spectra 425
# Computing power spectra 426
# Computing power spectra 427
# Computing power spectra 428
# Computing power spectra 429
# Computing power spectra 430
# Computing power spectra 431
# Computing power spectra 432
# Computing power spectra 433
# Computing power spectra 434
# Computing power spectra 435
# Computing power spectra 436
# Computing power spectra 437
# Computing power spectra 438
# Computing power spectra 439
# Computing power spectra 440
# Computing power spectra 441
# Computing power spectra 442
# Computing power spectra 443
# Computing power spectra 444
# Computing power spectra 445
# Computing power spectra 446
# Computing power spectra 447
# Computing power spectra 448
# Computing power spectra 449
# Computing power spectra 450
# Computing power spectra 451
# Computing power spectra 452
# Computing power spectra 453
# Computing power spectra 454
# Computing power spectra 455
# Computing power spectra 456
# Computing power spectra 457
# Computing power spectra 458
# Computing power spectra 459
# Computing power spectra 460
# Computing power spectra 461
# Computing power spectra 462
# Computing power spectra 463
# Computing power spectra 464
# Computing power spectra 465
# Computing power spectra 466
# Computing power spectra 467
# Computing power spectra 468
# Computing power spectra 469
# Computing power spectra 470
# Computing power spectra 471
# Computing power spectra 472
# Computing power spectra 473
# Computing power spectra 474
# Computing power spectra 475
# Computing power spectra 476
# Computing power spectra 477
# Computing power spectra 478
# Computing power spectra 479
# Computing power spectra 480
# Computing power spectra 481
# Computing power spectra 482
# Computing power spectra 483
# Computing power spectra 484
# Computing power spectra 485
# Computing power spectra 486
# Computing power spectra 487
# Computing power spectra 488
# Computing power spectra 489
# Computing power spectra 490
# Computing power spectra 491
# Computing power spectra 492
# Computing power spectra 493
# Converting maps 147
# Converting maps 148
# Converting maps 149
# Converting maps 150
# Converting maps 151
# Converting maps 152
# Converting maps 153
# Converting maps 154
# Converting maps 155
# Converting maps 156
# Converting maps 157
# Converting maps 158
# Converting maps 159
# Converting maps 160
# Converting maps 161
# Converting maps 162
# Converting maps 163
# Converting maps 164
# Converting maps 165
# Converting maps 166
# Converting maps 167
# Converting maps 168
# Converting maps 169
# Converting maps 170
# Converting maps 171
# Converting maps 172
# Converting maps 173
# Converting maps 174
# Converting maps 175
# Converting maps 176
# Converting maps 177
# Converting maps 178
# Converting maps 179
# Converting maps 180
# Computing power spectra 0
# Computing power spectra 1
# Computing power spectra 2
# Computing power spectra 3
# Computing power spectra 4
# Computing power spectra 5
# Computing power spectra 6
# Computing power spectra 7
# Computing power spectra 8
# Computing power spectra 9
# Computing power spectra 10
# Computing power spectra 11
# Computing power spectra 12
# Computing power spectra 13
# Computing power spectra 14
# Computing power spectra 15
# Computing power spectra 16
# Computing power spectra 17
# Computing power spectra 18
# Computing power spectra 19
# Computing power spectra 20
# Computing power spectra 21
# Computing power spectra 22
# Computing power spectra 23
# Computing power spectra 24
# Computing power spectra 25
# Computing power spectra 26
# Computing power spectra 27
# Computing power spectra 28
# Computing power spectra 29
# Computing power spectra 30
# Computing power spectra 31
# Computing power spectra 32
# Computing power spectra 33
# Computing power spectra 34
# Computing power spectra 35
# Computing power spectra 36
# Computing power spectra 37
# Computing power spectra 38
# Computing power spectra 39
# Computing power spectra 40
# Computing power spectra 41
# Computing power spectra 42
# Computing power spectra 43
# Computing power spectra 44
# Computing power spectra 45
# Computing power spectra 46
# Computing power spectra 47
# Computing power spectra 48
# Computing power spectra 49
# Computing power spectra 50
# Computing power spectra 51
# Computing power spectra 52
# Computing power spectra 53
# Computing power spectra 54
# Computing power spectra 55
# Computing power spectra 56
# Computing power spectra 57
# Computing power spectra 58
# Computing power spectra 59
# Computing power spectra 60
# Computing power spectra 61
# Computing power spectra 62
# Computing power spectra 63
# Computing power spectra 64
# Computing power spectra 65
# Computing power spectra 66
# Computing power spectra 67
# Computing power spectra 68
# Computing power spectra 69
# Computing power spectra 70
# Computing power spectra 71
# Computing power spectra 72
# Computing power spectra 73
# Computing power spectra 74
# Computing power spectra 75
# Computing power spectra 76
# Computing power spectra 77
# Computing power spectra 78
# Computing power spectra 79
# Computing power spectra 80
# Computing power spectra 81
# Computing power spectra 82
# Computing power spectra 83
# Computing power spectra 84
# Computing power spectra 85
# Computing power spectra 86
# Computing power spectra 87
# Computing power spectra 88
# Computing power spectra 89
# Computing power spectra 90
# Computing power spectra 91
# Computing power spectra 92
# Computing power spectra 93
# Computing power spectra 94
# Computing power spectra 95
# Computing power spectra 96
# Computing power spectra 97
# Computing power spectra 98
# Computing power spectra 99
# Computing power spectra 100
# Computing power spectra 101
# Computing power spectra 102
# Computing power spectra 103
# Computing power spectra 104
# Computing power spectra 105
# Computing power spectra 106
# Computing power spectra 107
# Computing power spectra 108
# Computing power spectra 109
# Computing power spectra 110
# Computing power spectra 111
# Computing power spectra 112
# Computing power spectra 113
# Computing power spectra 114
# Computing power spectra 115
# Computing power spectra 116
# Computing power spectra 117
# Computing power spectra 118
# Computing power spectra 119
# Computing power spectra 120
# Computing power spectra 121
# Computing power spectra 122
# Computing power spectra 123
# Computing power spectra 124
# Computing power spectra 125
# Computing power spectra 126
# Computing power spectra 127
# Computing power spectra 128
# Computing power spectra 129
# Computing power spectra 130
# Computing power spectra 131
# Computing power spectra 132
# Computing power spectra 133
# Computing power spectra 134
# Computing power spectra 135
# Computing power spectra 136
# Computing power spectra 137
# Computing power spectra 138
# Computing power spectra 139
# Computing power spectra 140
# Computing power spectra 141
# Computing power spectra 142
# Computing power spectra 143
# Computing power spectra 144
# Computing power spectra 145
# Computing power spectra 146
# Computing power spectra 147
# Computing power spectra 148
# Computing power spectra 149
# Computing power spectra 150
# Computing power spectra 151
# Computing power spectra 152
# Computing power spectra 153
# Computing power spectra 154
# Computing power spectra 155
# Computing power spectra 156
# Computing power spectra 157
# Computing power spectra 158
# Computing power spectra 159
# Computing power spectra 160
# Computing power spectra 161
# Computing power spectra 162
# Computing power spectra 163
# Computing power spectra 164
# Computing power spectra 165
# Computing power spectra 166
# Computing power spectra 167
# Computing power spectra 168
# Computing power spectra 169
# Computing power spectra 170
# Computing power spectra 171
# Computing power spectra 172
# Computing power spectra 173
# Computing power spectra 174
# Computing power spectra 175
# Computing power spectra 176
# Computing power spectra 177
# Computing power spectra 178
# Computing power spectra 179
# Computing power spectra 180
# Computing power spectra 181
# Computing power spectra 182
# Computing power spectra 183
# Computing power spectra 184
# Computing power spectra 185
# Computing power spectra 186
# Computing power spectra 187
# Computing power spectra 188
# Computing power spectra 189
# Computing power spectra 190
# Computing power spectra 191
# Computing power spectra 192
# Computing power spectra 193
# Computing power spectra 194
# Computing power spectra 195
# Computing power spectra 196
# Computing power spectra 197
# Computing power spectra 198
# Computing power spectra 199
# Computing power spectra 200
# Computing power spectra 201
# Computing power spectra 202
# Computing power spectra 203
# Computing power spectra 204
# Computing power spectra 205
# Computing power spectra 206
# Computing power spectra 207
# Computing power spectra 208
# Computing power spectra 209
# Computing power spectra 210
# Computing power spectra 211
# Computing power spectra 212
# Computing power spectra 213
# Computing power spectra 214
# Computing power spectra 215
# Computing power spectra 216
# Computing power spectra 217
# Computing power spectra 218
# Computing power spectra 219
# Computing power spectra 220
# Computing power spectra 221
# Computing power spectra 222
# Computing power spectra 223
# Computing power spectra 224
# Computing power spectra 225
# Computing power spectra 226
# Computing power spectra 227
# Computing power spectra 228
# Computing power spectra 229
# Computing power spectra 230
# Computing power spectra 231
# Computing power spectra 232
# Computing power spectra 233
# Computing power spectra 234
# Computing power spectra 235
# Computing power spectra 236
# Computing power spectra 237
# Computing power spectra 238
# Computing power spectra 239
# Computing power spectra 240
# Computing power spectra 241
# Computing power spectra 242
# Computing power spectra 243
# Computing power spectra 244
# Computing power spectra 245
# Computing power spectra 246
# Computing power spectra 247
# Computing power spectra 248
# Computing power spectra 249
# Computing power spectra 250
# Computing power spectra 251
# Computing power spectra 252
# Computing power spectra 253
# Computing power spectra 254
# Computing power spectra 255
# Computing power spectra 256
# Computing power spectra 257
# Computing power spectra 258
# Computing power spectra 259
# Computing power spectra 260
# Computing power spectra 261
# Computing power spectra 262
# Computing power spectra 263
# Computing power spectra 264
# Computing power spectra 265
# Computing power spectra 266
# Computing power spectra 267
# Computing power spectra 268
# Computing power spectra 269
# Computing power spectra 270
# Computing power spectra 271
# Computing power spectra 272
# Computing power spectra 273
# Computing power spectra 274
# Computing power spectra 275
# Computing power spectra 276
# Computing power spectra 277
# Computing power spectra 278
# Computing power spectra 279
# Computing power spectra 280
# Computing power spectra 281
# Computing power spectra 282
# Computing power spectra 283
# Computing power spectra 284
# Computing power spectra 285
# Computing power spectra 286
# Computing power spectra 287
# Computing power spectra 288
# Computing power spectra 289
# Computing power spectra 290
# Computing power spectra 291
# Computing power spectra 292
# Computing power spectra 293
# Computing power spectra 294
# Computing power spectra 295
# Computing power spectra 296
# Computing power spectra 297
# Computing power spectra 298
# Computing power spectra 299
# Computing power spectra 300
# Computing power spectra 301
# Computing power spectra 302
# Computing power spectra 303
# Computing power spectra 304
# Computing power spectra 305
# Computing power spectra 306
# Computing power spectra 307
# Computing power spectra 308
# Computing power spectra 309
# Computing power spectra 310
# Computing power spectra 311
# Computing power spectra 312
# Computing power spectra 313
# Computing power spectra 314
# Computing power spectra 315
# Computing power spectra 316
# Computing power spectra 317
# Computing power spectra 318
# Computing power spectra 319
# Computing power spectra 320
# Computing power spectra 321
# Computing power spectra 322
# Computing power spectra 323
# Computing power spectra 324
# Computing power spectra 325
# Computing power spectra 326
# Computing power spectra 327
# Computing power spectra 328
# Computing power spectra 329
# Computing power spectra 330
# Computing power spectra 331
# Computing power spectra 332
# Computing power spectra 333
# Computing power spectra 334
# Computing power spectra 335
# Computing power spectra 336
# Computing power spectra 337
# Computing power spectra 338
# Computing power spectra 339
# Computing power spectra 340
# Computing power spectra 341
# Computing power spectra 342
# Computing power spectra 343
# Computing power spectra 344
# Computing power spectra 345
# Computing power spectra 346
# Computing power spectra 347
# Computing power spectra 348
# Computing power spectra 349
# Computing power spectra 350
# Computing power spectra 351
# Computing power spectra 352
# Computing power spectra 353
# Computing power spectra 354
# Computing power spectra 355
# Computing power spectra 356
# Computing power spectra 357
# Computing power spectra 358
# Computing power spectra 359
# Computing power spectra 360
# Computing power spectra 361
# Computing power spectra 362
# Computing power spectra 363
# Computing power spectra 364
# Computing power spectra 365
# Computing power spectra 366
# Computing power spectra 367
# Computing power spectra 368
# Computing power spectra 369
# Computing power spectra 370
# Computing power spectra 371
# Computing power spectra 372
# Computing power spectra 373
# Computing power spectra 374
# Computing power spectra 375
# Computing power spectra 376
# Computing power spectra 377
# Computing power spectra 378
# Computing power spectra 379
# Computing power spectra 380
# Computing power spectra 381
# Computing power spectra 382
# Computing power spectra 383
# Computing power spectra 384
# Computing power spectra 385
# Computing power spectra 386
# Computing power spectra 387
# Computing power spectra 388
# Computing power spectra 389
# Computing power spectra 390
# Computing power spectra 391
# Computing power spectra 392
# Computing power spectra 393
# Computing power spectra 394
# Computing power spectra 395
# Computing power spectra 396
# Computing power spectra 397
# Computing power spectra 398
# Computing power spectra 399
# Computing power spectra 400
# Computing power spectra 401
# Computing power spectra 402
# Computing power spectra 403
# Computing power spectra 404
# Computing power spectra 405
# Computing power spectra 406
# Computing power spectra 407
# Computing power spectra 408
# Computing power spectra 409
# Computing power spectra 410
# Computing power spectra 411
# Computing power spectra 412
# Computing power spectra 413
# Computing power spectra 414
# Computing power spectra 415
# Computing power spectra 416
# Computing power spectra 417
# Computing power spectra 418
# Computing power spectra 419
# Computing power spectra 420
# Computing power spectra 421
# Computing power spectra 422
# Computing power spectra 423
# Computing power spectra 424
# Computing power spectra 425
# Computing power spectra 426
# Computing power spectra 427
# Computing power spectra 428
# Computing power spectra 429
# Computing power spectra 430
# Computing power spectra 431
# Computing power spectra 432
# Computing power spectra 433
# Computing power spectra 434
# Computing power spectra 435
# Computing power spectra 436
# Computing power spectra 437
# Computing power spectra 438
# Computing power spectra 439
# Computing power spectra 440
# Computing power spectra 441
# Computing power spectra 442
# Computing power spectra 443
# Computing power spectra 444
# Computing power spectra 445
# Computing power spectra 446
# Computing power spectra 447
# Computing power spectra 448
# Computing power spectra 449
# Computing power spectra 450
# Computing power spectra 451
# Computing power spectra 452
# Computing power spectra 453
# Computing power spectra 454
# Computing power spectra 455
# Computing power spectra 456
# Computing power spectra 457
# Computing power spectra 458
# Computing power spectra 459
# Computing power spectra 460
# Computing power spectra 461
# Computing power spectra 462
# Computing power spectra 463
# Computing power spectra 464
# Computing power spectra 465
# Computing power spectra 466
# Computing power spectra 467
# Computing power spectra 468
# Computing power spectra 469
# Computing power spectra 470
# Computing power spectra 471
# Computing power spectra 472
# Computing power spectra 473
# Computing power spectra 474
# Computing power spectra 475
# Computing power spectra 476
# Computing power spectra 477
# Computing power spectra 478
# Computing power spectra 479
# Computing power spectra 480
# Computing power spectra 481
# Computing power spectra 482
# Computing power spectra 483
# Computing power spectra 484
# Computing power spectra 485
# Computing power spectra 486
# Computing power spectra 487
# Computing power spectra 488
# Computing power spectra 489
# Computing power spectra 490
# Computing power spectra 491
# Computing power spectra 492
# Computing power spectra 493
# Computing power spectra 494
# Computing power spectra 495
# Computing power spectra 496
# Computing power spectra 497
# Computing power spectra 498
# Computing power spectra 499
# Computing power spectra 500
# Computing power spectra 501
# Computing power spectra 502
# Computing power spectra 503
# Computing power spectra 504
# Computing power spectra 505
# Computing power spectra 506
# Computing power spectra 507
# Computing power spectra 508
# Computing power spectra 509
# Computing power spectra 510
# Computing power spectra 511
# Computing power spectra 512
# Converting maps 0
# Converting maps 1
# Converting maps 2
# Converting maps 3
# Converting maps 4
# Converting maps 5
# Converting maps 6
# Converting maps 7
# Converting maps 8
# Converting maps 9
# Converting maps 10
# Converting maps 11
# Converting maps 12
# Converting maps 13
# Converting maps 14
# Converting maps 15
# Converting maps 16
# Converting maps 17
# Computing power spectra 6
# Computing power spectra 7
# Computing power spectra 8
# Computing power spectra 9
# Computing power spectra 10
# Computing power spectra 11
# Computing power spectra 12
# Computing power spectra 13
# Computing power spectra 14
# Computing power spectra 15
# Computing power spectra 16
# Computing power spectra 17
# Computing power spectra 18
# Computing power spectra 19
# Computing power spectra 20
# Computing power spectra 21
# Computing power spectra 22
# Computing power spectra 23
# Computing power spectra 24
# Computing power spectra 25
# Computing power spectra 26
# Computing power spectra 27
# Computing power spectra 28
# Computing power spectra 29
# Computing power spectra 30
# Computing power spectra 31
# Computing power spectra 32
# Computing power spectra 33
# Computing power spectra 34
# Computing power spectra 35
# Computing power spectra 36
# Computing power spectra 37
# Computing power spectra 38
# Computing power spectra 39
# Computing power spectra 40
# Computing power spectra 41
# Computing power spectra 42
# Computing power spectra 43
# Computing power spectra 44
# Computing power spectra 45
# Computing power spectra 46
# Computing power spectra 47
# Computing power spectra 48
# Computing power spectra 49
# Computing power spectra 50
# Computing power spectra 51
# Computing power spectra 52
# Computing power spectra 53
# Computing power spectra 54
# Computing power spectra 55
# Computing power spectra 56
# Computing power spectra 57
# Computing power spectra 58
# Computing power spectra 59
# Computing power spectra 60
# Computing power spectra 61
# Computing power spectra 62
# Computing power spectra 63
# Computing power spectra 64
# Computing power spectra 65
# Computing power spectra 66
# Computing power spectra 67
# Computing power spectra 68
# Computing power spectra 69
# Computing power spectra 70
# Computing power spectra 71
# Computing power spectra 72
# Computing power spectra 73
# Computing power spectra 74
# Computing power spectra 75
# Computing power spectra 76
# Computing power spectra 77
# Computing power spectra 78
# Computing power spectra 79
# Computing power spectra 80
# Computing power spectra 81
# Computing power spectra 82
# Computing power spectra 83
# Computing power spectra 84
# Computing power spectra 85
# Computing power spectra 86
# Computing power spectra 87
# Computing power spectra 88
# Computing power spectra 89
# Computing power spectra 90
# Computing power spectra 91
# Computing power spectra 92
# Computing power spectra 93
# Computing power spectra 94
# Computing power spectra 95
# Computing power spectra 96
# Computing power spectra 97
# Computing power spectra 98
# Computing power spectra 99
# Computing power spectra 100
# Computing power spectra 101
# Computing power spectra 102
# Computing power spectra 103
# Computing power spectra 104
# Computing power spectra 105
# Computing power spectra 106
# Computing power spectra 107
# Computing power spectra 108
# Computing power spectra 109
# Computing power spectra 110
# Computing power spectra 111
# Computing power spectra 112
# Computing power spectra 113
# Computing power spectra 114
# Computing power spectra 115
# Computing power spectra 116
# Computing power spectra 117
# Computing power spectra 118
# Computing power spectra 119
# Computing power spectra 120
# Computing power spectra 121
# Computing power spectra 122
# Computing power spectra 123
# Computing power spectra 124
# Computing power spectra 125
# Computing power spectra 126
# Computing power spectra 127
# Computing power spectra 128
# Computing power spectra 129
# Computing power spectra 130
# Computing power spectra 131
# Computing power spectra 132
# Computing power spectra 133
# Computing power spectra 134
# Computing power spectra 135
# Computing power spectra 136
# Computing power spectra 137
# Computing power spectra 138
# Computing power spectra 139
# Computing power spectra 140
# Computing power spectra 141
# Computing power spectra 142
# Computing power spectra 143
# Computing power spectra 144
# Computing power spectra 145
# Computing power spectra 146
# Computing power spectra 147
# Computing power spectra 148
# Computing power spectra 149
# Computing power spectra 150
# Computing power spectra 151
# Computing power spectra 152
# Computing power spectra 153
# Computing power spectra 154
# Computing power spectra 155
# Computing power spectra 156
# Computing power spectra 157
# Computing power spectra 158
# Computing power spectra 159
# Computing power spectra 160
# Computing power spectra 161
# Computing power spectra 162
# Computing power spectra 163
# Computing power spectra 164
# Computing power spectra 165
# Computing power spectra 166
# Computing power spectra 167
# Computing power spectra 168
# Computing power spectra 169
# Computing power spectra 170
# Computing power spectra 171
# Computing power spectra 172
# Computing power spectra 173
# Computing power spectra 174
# Computing power spectra 175
# Computing power spectra 176
# Computing power spectra 177
# Computing power spectra 178
# Computing power spectra 179
# Computing power spectra 180
# Computing power spectra 181
# Computing power spectra 182
# Computing power spectra 183
# Computing power spectra 184
# Computing power spectra 185
# Computing power spectra 186
# Computing power spectra 187
# Computing power spectra 188
# Computing power spectra 189
# Computing power spectra 190
# Computing power spectra 191
# Computing power spectra 192
# Computing power spectra 193
# Computing power spectra 194
# Computing power spectra 195
# Computing power spectra 196
# Computing power spectra 197
# Computing power spectra 198
# Computing power spectra 199
# Computing power spectra 200
# Computing power spectra 201
# Computing power spectra 202
# Computing power spectra 203
# Computing power spectra 204
# Computing power spectra 205
# Computing power spectra 206
# Computing power spectra 207
# Computing power spectra 208
# Computing power spectra 209
# Computing power spectra 210
# Computing power spectra 211
# Computing power spectra 212
# Computing power spectra 213
# Computing power spectra 214
# Computing power spectra 215
# Computing power spectra 216
# Computing power spectra 217
# Computing power spectra 218
# Computing power spectra 219
# Computing power spectra 220
# Computing power spectra 221
# Computing power spectra 222
# Computing power spectra 223
# Computing power spectra 224
# Computing power spectra 225
# Computing power spectra 226
# Computing power spectra 227
# Computing power spectra 228
# Computing power spectra 229
# Computing power spectra 230
# Computing power spectra 231
# Computing power spectra 232
# Computing power spectra 233
# Computing power spectra 234
# Computing power spectra 235
# Computing power spectra 236
# Computing power spectra 237
# Computing power spectra 238
# Computing power spectra 239
# Computing power spectra 240
# Computing power spectra 241
# Computing power spectra 242
# Computing power spectra 243
# Computing power spectra 244
# Computing power spectra 245
# Computing power spectra 246
# Computing power spectra 247
# Computing power spectra 248
# Computing power spectra 249
# Computing power spectra 250
# Computing power spectra 251
# Computing power spectra 252
# Computing power spectra 253
# Computing power spectra 254
# Computing power spectra 255
# Computing power spectra 256
# Computing power spectra 257
# Computing power spectra 258
# Computing power spectra 259
# Computing power spectra 260
# Computing power spectra 261
# Computing power spectra 262
# Computing power spectra 263
# Computing power spectra 264
# Computing power spectra 265
# Computing power spectra 266
# Computing power spectra 267
# Computing power spectra 268
# Computing power spectra 269
# Computing power spectra 270
# Computing power spectra 271
# Computing power spectra 272
# Computing power spectra 273
# Computing power spectra 274
# Computing power spectra 275
# Computing power spectra 276
# Computing power spectra 277
# Computing power spectra 278
# Computing power spectra 279
# Computing power spectra 280
# Computing power spectra 281
# Computing power spectra 282
# Computing power spectra 283
# Computing power spectra 284
# Computing power spectra 285
# Computing power spectra 286
# Computing power spectra 287
# Computing power spectra 288
# Computing power spectra 289
# Computing power spectra 290
# Computing power spectra 291
# Computing power spectra 292
# Computing power spectra 293
# Computing power spectra 294
# Computing power spectra 295
# Computing power spectra 296
# Computing power spectra 297
# Computing power spectra 298
# Computing power spectra 299
# Computing power spectra 300
# Computing power spectra 301
# Computing power spectra 302
# Computing power spectra 303
# Computing power spectra 304
# Computing power spectra 305
# Computing power spectra 306
# Computing power spectra 307
# Computing power spectra 308
# Computing power spectra 309
# Computing power spectra 310
# Computing power spectra 311
# Computing power spectra 312
# Computing power spectra 313
# Computing power spectra 314
# Computing power spectra 315
# Computing power spectra 316
# Computing power spectra 317
# Computing power spectra 318
# Computing power spectra 319
# Computing power spectra 320
# Computing power spectra 321
# Computing power spectra 322
# Computing power spectra 323
# Computing power spectra 324
# Computing power spectra 325
# Computing power spectra 326
# Computing power spectra 327
# Computing power spectra 328
# Computing power spectra 329
# Computing power spectra 330
# Computing power spectra 331
# Computing power spectra 332
# Computing power spectra 333
# Computing power spectra 334
# Computing power spectra 335
# Computing power spectra 336
# Computing power spectra 337
# Computing power spectra 338
# Computing power spectra 339
# Computing power spectra 340
# Computing power spectra 341
# Computing power spectra 342
# Computing power spectra 343
# Computing power spectra 344
# Computing power spectra 345
# Computing power spectra 346
# Computing power spectra 347
# Computing power spectra 348
# Computing power spectra 349
# Computing power spectra 350
# Computing power spectra 351
# Computing power spectra 352
# Computing power spectra 353
# Computing power spectra 354
# Computing power spectra 355
# Computing power spectra 356
# Computing power spectra 357
# Computing power spectra 358
# Computing power spectra 359
# Computing power spectra 360
# Computing power spectra 361
# Computing power spectra 362
# Computing power spectra 363
# Computing power spectra 364
# Computing power spectra 365
# Computing power spectra 366
# Computing power spectra 367
# Computing power spectra 368
# Computing power spectra 369
# Computing power spectra 370
# Computing power spectra 371
# Computing power spectra 372
# Computing power spectra 373
# Computing power spectra 374
# Computing power spectra 375
# Computing power spectra 376
# Computing power spectra 377
# Computing power spectra 378
# Computing power spectra 379
# Computing power spectra 380
# Computing power spectra 381
# Computing power spectra 382
# Computing power spectra 383
# Computing power spectra 384
# Computing power spectra 385
# Computing power spectra 386
# Computing power spectra 387
# Computing power spectra 388
# Computing power spectra 389
# Computing power spectra 390
# Computing power spectra 391
# Computing power spectra 392
# Computing power spectra 393
# Computing power spectra 394
# Computing power spectra 395
# Computing power spectra 396
# Computing power spectra 397
# Computing power spectra 398
# Computing power spectra 399
# Computing power spectra 400
# Computing power spectra 401
# Computing power spectra 402
# Computing power spectra 403
# Computing power spectra 404
# Computing power spectra 405
# Computing power spectra 406
# Computing power spectra 407
# Computing power spectra 408
# Computing power spectra 409
# Computing power spectra 410
# Computing power spectra 411
# Computing power spectra 412
# Computing power spectra 413
# Computing power spectra 414
# Computing power spectra 415
# Computing power spectra 416
# Computing power spectra 417
# Computing power spectra 418
# Computing power spectra 419
# Computing power spectra 420
# Computing power spectra 421
# Computing power spectra 422
# Computing power spectra 423
# Computing power spectra 424
# Computing power spectra 425
# Computing power spectra 426
# Computing power spectra 427
# Computing power spectra 428
# Computing power spectra 429
# Computing power spectra 430
# Computing power spectra 431
# Computing power spectra 432
# Computing power spectra 433
# Computing power spectra 434
# Computing power spectra 435
# Computing power spectra 436
# Computing power spectra 437
# Computing power spectra 438
# Computing power spectra 439
# Computing power spectra 440
# Computing power spectra 441
# Computing power spectra 442
# Computing power spectra 443
# Computing power spectra 444
# Computing power spectra 445
# Computing power spectra 446
# Computing power spectra 447
# Computing power spectra 448
# Computing power spectra 449
# Computing power spectra 450
# Computing power spectra 451
# Computing power spectra 452
# Computing power spectra 453
# Computing power spectra 454
# Computing power spectra 455
# Computing power spectra 456
# Computing power spectra 457
# Computing power spectra 458
# Computing power spectra 459
# Computing power spectra 460
# Computing power spectra 461
# Computing power spectra 462
# Computing power spectra 463
# Computing power spectra 464
# Computing power spectra 465
# Computing power spectra 466
# Computing power spectra 467
# Computing power spectra 468
# Computing power spectra 469
# Computing power spectra 470
# Computing power spectra 471
# Computing power spectra 472
# Computing power spectra 473
# Computing power spectra 474
# Computing power spectra 475
# Computing power spectra 476
# Computing power spectra 477
# Computing power spectra 478
# Computing power spectra 479
# Computing power spectra 480
# Computing power spectra 481
# Computing power spectra 482
# Computing power spectra 483
# Computing power spectra 484
# Computing power spectra 485
# Computing power spectra 486
# Computing power spectra 487
# Computing power spectra 488
# Computing power spectra 489
# Computing power spectra 490
# Computing power spectra 491
# Computing power spectra 492
# Computing power spectra 493
# Computing power spectra 494
# Computing power spectra 495
# Computing power spectra 496
# Computing power spectra 497
# Computing power spectra 498
# Computing power spectra 499
# Computing power spectra 500
# Computing power spectra 501
# Computing power spectra 502
# Computing power spectra 503
# Computing power spectra 504
# Computing power spectra 505
# Computing power spectra 506
# Computing power spectra 507
# Computing power spectra 508
# Computing power spectra 509
# Computing power spectra 510
# Computing power spectra 511
# Computing power spectra 512

# %%
plt.plot(cl_noise[:,0,0], label='noise')
plt.plot(cl_fgds[:,0,0], label='fgds')
# plt.plot(cl_hi[2:,0,0], label='HI')
plt.yscale('log')
plt.legend()

# %%
snr=np.mean(cl_fgds[:,0,0]/cl_noise[:,0,0])
print(snr)
# Out:
# 49.87005741301073

# %%
def diagonalize_matrices(cl, nfreqs):
    cl_diag=np.zeros((lmax+1, nfreqs, nfreqs))
    for l in range (lmax+1):
        print(f"Diagonalizing matrix {l}")
        cl_diag[l,:,:]= np.identity(nfreqs)*cl[l,:,:]
    return cl_diag

# %%
noise_d= diagonalize_matrices(cl_noise, nfreqs)
hi_d= diagonalize_matrices(cl_noise, nfreqs)
# Out:
# Diagonalizing matrix 0
# Diagonalizing matrix 1
# Diagonalizing matrix 2
# Diagonalizing matrix 3
# Diagonalizing matrix 4
# Diagonalizing matrix 5
# Diagonalizing matrix 6
# Diagonalizing matrix 7
# Diagonalizing matrix 8
# Diagonalizing matrix 9
# Diagonalizing matrix 10
# Diagonalizing matrix 11
# Diagonalizing matrix 12
# Diagonalizing matrix 482
# Diagonalizing matrix 483
# Diagonalizing matrix 484
# Diagonalizing matrix 485
# Diagonalizing matrix 486
# Diagonalizing matrix 487
# Diagonalizing matrix 488
# Diagonalizing matrix 489
# Diagonalizing matrix 490
# Diagonalizing matrix 491
# Diagonalizing matrix 492
# Diagonalizing matrix 493
# Diagonalizing matrix 494
# Diagonalizing matrix 495
# Diagonalizing matrix 496
# Diagonalizing matrix 497
# Diagonalizing matrix 498
# Diagonalizing matrix 499
# Diagonalizing matrix 500
# Diagonalizing matrix 501
# Diagonalizing matrix 502
# Diagonalizing matrix 503
# Diagonalizing matrix 504
# Diagonalizing matrix 505
# Diagonalizing matrix 506
# Diagonalizing matrix 507
# Diagonalizing matrix 508
# Diagonalizing matrix 509
# Diagonalizing matrix 510
# Diagonalizing matrix 511
# Diagonalizing matrix 512

# %%
delta_ell=10

# %%
def bin_spectra(cl,nside, delta):
    b= nmt.NmtBin.from_lmax_linear(lmax, nlb=delta)
    n_bins = b.get_n_bands()
    leff = b.get_effective_ells()
    cl_binned= np.zeros((n_bins, nfreqs, nfreqs))

    for i in range(nfreqs):
        for j in range(nfreqs):
            cl_binned[:, i, j] = b.bin_cell(cl[:, i, j])
            
    return leff,n_bins,cl_binned

# %%
leff,n_bins, noise_binned= bin_spectra(noise_d, nside, delta_ell)
*_, fgds_binned= bin_spectra(cl_fgds, nside, delta_ell)
*_, hi_binned= bin_spectra(cl_fgds, nside, delta_ell)

# %%
# np.save('fgds_binned.npy', fgds_binned)
# np.save('noise_binned.npy', noise_binned)

# %%
total=fgds+noise_maps_1+hi_maps
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
c_l_hat= compute_covariance(total, lmax, almsize, nfreqs)
# Out:
# Converting maps 0
# Converting maps 1
# Converting maps 2
# Converting maps 3
# Converting maps 4
# Converting maps 5
# Converting maps 6
# Converting maps 7
# Converting maps 8
# Converting maps 9
# Converting maps 10
# Converting maps 11
# Converting maps 12
# Converting maps 13
# Converting maps 14
# Converting maps 15
# Converting maps 16
# Converting maps 17
# Converting maps 18
# Converting maps 19
# Converting maps 20
# Converting maps 21
# Converting maps 22
# Converting maps 23
# Converting maps 24
# Converting maps 25
# Converting maps 26
# Converting maps 27
# Converting maps 28
# Converting maps 29
# Converting maps 30
# Converting maps 31
# Converting maps 32
# Converting maps 33
# Converting maps 34
# Converting maps 35
# Converting maps 36
# Converting maps 37
# Converting maps 38
# Converting maps 39
# Converting maps 40
# Converting maps 41
# Converting maps 42
# Converting maps 43
# Converting maps 44
# Converting maps 45
# Converting maps 46
# Converting maps 47
# Converting maps 48
# Converting maps 49
# Converting maps 50
# Converting maps 51
# Converting maps 52
# Converting maps 53
# Converting maps 54
# Converting maps 55
# Converting maps 56
# Converting maps 57
# Converting maps 58
# Converting maps 59
# Converting maps 60
# Converting maps 61
# Converting maps 62
# Converting maps 63
# Converting maps 64
# Converting maps 65
# Converting maps 66
# Converting maps 67
# Converting maps 68
# Converting maps 69
# Converting maps 70
# Converting maps 71
# Converting maps 72
# Converting maps 73
# Converting maps 74
# Converting maps 75
# Converting maps 76
# Converting maps 77
# Converting maps 78
# Converting maps 79
# Converting maps 80
# Converting maps 81
# Converting maps 82
# Converting maps 83
# Converting maps 84
# Converting maps 85
# Converting maps 86
# Converting maps 87
# Converting maps 88
# Converting maps 89
# Converting maps 90
# Converting maps 91
# Converting maps 92
# Converting maps 93
# Converting maps 94
# Converting maps 95
# Converting maps 96
# Converting maps 97
# Converting maps 98
# Converting maps 99
# Converting maps 100
# Converting maps 101
# Converting maps 102
# Converting maps 103
# Converting maps 104
# Converting maps 105
# Converting maps 106
# Converting maps 107
# Converting maps 108
# Converting maps 109
# Converting maps 110
# Converting maps 111
# Converting maps 112
# Converting maps 113
# Converting maps 114
# Converting maps 115
# Converting maps 116
# Converting maps 117
# Converting maps 118
# Converting maps 119
# Converting maps 120
# Converting maps 121
# Converting maps 122
# Converting maps 123
# Converting maps 124
# Converting maps 125
# Converting maps 126
# Converting maps 127
# Converting maps 128
# Converting maps 129
# Converting maps 130
# Converting maps 131
# Converting maps 132
# Converting maps 133
# Converting maps 134
# Converting maps 135
# Converting maps 136
# Converting maps 137
# Converting maps 138
# Converting maps 139
# Converting maps 140
# Converting maps 141
# Converting maps 142
# Converting maps 143
# Converting maps 144
# Converting maps 145
# Converting maps 146
# Converting maps 147
# Converting maps 148
# Converting maps 149
# Converting maps 150
# Converting maps 151
# Converting maps 152
# Converting maps 153
# Converting maps 154
# Converting maps 155
# Converting maps 156
# Converting maps 157
# Converting maps 158
# Converting maps 159
# Converting maps 160
# Converting maps 161
# Converting maps 162
# Converting maps 163
# Converting maps 164
# Converting maps 165
# Converting maps 166
# Converting maps 167
# Converting maps 168
# Converting maps 169
# Converting maps 170
# Converting maps 171
# Converting maps 172
# Converting maps 173
# Converting maps 174
# Converting maps 175
# Converting maps 176
# Converting maps 177
# Converting maps 178
# Converting maps 179
# Converting maps 180
# Computing power spectra 0
# Computing power spectra 1
# Computing power spectra 2
# Computing power spectra 3
# Computing power spectra 4
# Computing power spectra 5
# Computing power spectra 6
# Computing power spectra 7
# Computing power spectra 8
# Computing power spectra 9
# Computing power spectra 10
# Computing power spectra 11
# Computing power spectra 12
# Computing power spectra 13
# Computing power spectra 14
# Computing power spectra 15
# Computing power spectra 16
# Computing power spectra 17
# Computing power spectra 18
# Computing power spectra 19
# Computing power spectra 20
# Computing power spectra 21
# Computing power spectra 22
# Computing power spectra 23
# Computing power spectra 24
# Computing power spectra 25
# Computing power spectra 26
# Computing power spectra 27
# Computing power spectra 28
# Computing power spectra 29
# Computing power spectra 30
# Computing power spectra 31
# Computing power spectra 32
# Computing power spectra 33
# Computing power spectra 34
# Computing power spectra 35
# Computing power spectra 36
# Computing power spectra 37
# Computing power spectra 38
# Computing power spectra 39
# Computing power spectra 40
# Computing power spectra 41
# Computing power spectra 42
# Computing power spectra 43
# Computing power spectra 44
# Computing power spectra 45
# Computing power spectra 46
# Computing power spectra 47
# Computing power spectra 48
# Computing power spectra 49
# Computing power spectra 50
# Computing power spectra 51
# Computing power spectra 52
# Computing power spectra 53
# Computing power spectra 54
# Computing power spectra 55
# Computing power spectra 56
# Computing power spectra 57
# Computing power spectra 58
# Computing power spectra 59
# Computing power spectra 60
# Computing power spectra 61
# Computing power spectra 62
# Computing power spectra 63
# Computing power spectra 64
# Computing power spectra 65
# Computing power spectra 66
# Computing power spectra 67
# Computing power spectra 68
# Computing power spectra 69
# Computing power spectra 70
# Computing power spectra 71
# Computing power spectra 72
# Computing power spectra 73
# Computing power spectra 74
# Computing power spectra 75
# Computing power spectra 76
# Computing power spectra 77
# Computing power spectra 78
# Computing power spectra 79
# Computing power spectra 80
# Computing power spectra 81
# Computing power spectra 82
# Computing power spectra 83
# Computing power spectra 84
# Computing power spectra 85
# Computing power spectra 86
# Computing power spectra 87
# Computing power spectra 88
# Computing power spectra 89
# Computing power spectra 90
# Computing power spectra 91
# Computing power spectra 92
# Computing power spectra 93
# Computing power spectra 94
# Computing power spectra 95
# Computing power spectra 96
# Computing power spectra 97
# Computing power spectra 98
# Computing power spectra 99
# Computing power spectra 100
# Computing power spectra 101
# Computing power spectra 102
# Computing power spectra 103
# Computing power spectra 104
# Computing power spectra 105
# Computing power spectra 106
# Computing power spectra 107
# Computing power spectra 108
# Computing power spectra 109
# Computing power spectra 110
# Computing power spectra 111
# Computing power spectra 112
# Computing power spectra 113
# Computing power spectra 114
# Computing power spectra 115
# Computing power spectra 116
# Computing power spectra 117
# Computing power spectra 118
# Computing power spectra 119
# Computing power spectra 120
# Computing power spectra 121
# Computing power spectra 122
# Computing power spectra 123
# Computing power spectra 124
# Computing power spectra 125
# Computing power spectra 126
# Computing power spectra 127
# Computing power spectra 128
# Computing power spectra 129
# Computing power spectra 130
# Computing power spectra 131
# Computing power spectra 132
# Computing power spectra 133
# Computing power spectra 134
# Computing power spectra 135
# Computing power spectra 136
# Computing power spectra 137
# Computing power spectra 138
# Computing power spectra 139
# Computing power spectra 140
# Computing power spectra 141
# Computing power spectra 142
# Computing power spectra 143
# Computing power spectra 144
# Computing power spectra 145
# Computing power spectra 146
# Computing power spectra 147
# Computing power spectra 148
# Computing power spectra 149
# Computing power spectra 150
# Computing power spectra 151
# Computing power spectra 152
# Computing power spectra 153
# Computing power spectra 154
# Computing power spectra 155
# Computing power spectra 156
# Computing power spectra 157
# Computing power spectra 158
# Computing power spectra 159
# Computing power spectra 160
# Computing power spectra 161
# Computing power spectra 162
# Computing power spectra 163
# Computing power spectra 164
# Computing power spectra 165
# Computing power spectra 166
# Computing power spectra 167
# Computing power spectra 168
# Computing power spectra 169
# Computing power spectra 170
# Computing power spectra 171
# Computing power spectra 172
# Computing power spectra 173
# Computing power spectra 174
# Computing power spectra 175
# Computing power spectra 176
# Computing power spectra 177
# Computing power spectra 178
# Computing power spectra 179
# Computing power spectra 180
# Computing power spectra 181
# Computing power spectra 182
# Computing power spectra 183
# Computing power spectra 184
# Computing power spectra 185
# Computing power spectra 186
# Computing power spectra 187
# Computing power spectra 188
# Computing power spectra 189
# Computing power spectra 190
# Computing power spectra 191
# Computing power spectra 192
# Computing power spectra 193
# Computing power spectra 194
# Computing power spectra 195
# Computing power spectra 196
# Computing power spectra 197
# Computing power spectra 198
# Computing power spectra 199
# Computing power spectra 200
# Computing power spectra 201
# Computing power spectra 202
# Computing power spectra 203
# Computing power spectra 204
# Computing power spectra 205
# Computing power spectra 206
# Computing power spectra 207
# Computing power spectra 208
# Computing power spectra 209
# Computing power spectra 210
# Computing power spectra 211
# Computing power spectra 212
# Computing power spectra 213
# Computing power spectra 214
# Computing power spectra 215
# Computing power spectra 216
# Computing power spectra 217
# Computing power spectra 218
# Computing power spectra 219
# Computing power spectra 220
# Computing power spectra 221
# Computing power spectra 222
# Computing power spectra 223
# Computing power spectra 224
# Computing power spectra 225
# Computing power spectra 226
# Computing power spectra 227
# Computing power spectra 228
# Computing power spectra 229
# Computing power spectra 230
# Computing power spectra 231
# Computing power spectra 232
# Computing power spectra 233
# Computing power spectra 234
# Computing power spectra 235
# Computing power spectra 236
# Computing power spectra 237
# Computing power spectra 238
# Computing power spectra 239
# Computing power spectra 240
# Computing power spectra 241
# Computing power spectra 242
# Computing power spectra 243
# Computing power spectra 244
# Computing power spectra 245
# Computing power spectra 246
# Computing power spectra 247
# Computing power spectra 248
# Computing power spectra 249
# Computing power spectra 250
# Computing power spectra 251
# Computing power spectra 252
# Computing power spectra 253
# Computing power spectra 254
# Computing power spectra 255
# Computing power spectra 256
# Computing power spectra 257
# Computing power spectra 258
# Computing power spectra 259
# Computing power spectra 260
# Computing power spectra 261
# Computing power spectra 262
# Computing power spectra 263
# Computing power spectra 264
# Computing power spectra 265
# Computing power spectra 266
# Computing power spectra 267
# Computing power spectra 268
# Computing power spectra 269
# Computing power spectra 270
# Computing power spectra 271
# Computing power spectra 272
# Computing power spectra 273
# Computing power spectra 274
# Computing power spectra 275
# Computing power spectra 276
# Computing power spectra 277
# Computing power spectra 278
# Computing power spectra 279
# Computing power spectra 280
# Computing power spectra 281
# Computing power spectra 282
# Computing power spectra 283
# Computing power spectra 284
# Computing power spectra 285
# Computing power spectra 286
# Computing power spectra 287
# Computing power spectra 288
# Computing power spectra 289
# Computing power spectra 290
# Computing power spectra 291
# Computing power spectra 292
# Computing power spectra 293
# Computing power spectra 294
# Computing power spectra 295
# Computing power spectra 296
# Computing power spectra 297
# Computing power spectra 298
# Computing power spectra 299
# Computing power spectra 300
# Computing power spectra 301
# Computing power spectra 302
# Computing power spectra 303
# Computing power spectra 304
# Computing power spectra 305
# Computing power spectra 306
# Computing power spectra 307
# Computing power spectra 308
# Computing power spectra 309
# Computing power spectra 310
# Computing power spectra 311
# Computing power spectra 312
# Computing power spectra 313
# Computing power spectra 314
# Computing power spectra 315
# Computing power spectra 316
# Computing power spectra 317
# Computing power spectra 318
# Computing power spectra 319
# Computing power spectra 320
# Computing power spectra 321
# Computing power spectra 322
# Computing power spectra 323
# Computing power spectra 324
# Computing power spectra 325
# Computing power spectra 326
# Computing power spectra 327
# Computing power spectra 328
# Computing power spectra 329
# Computing power spectra 330
# Computing power spectra 331
# Computing power spectra 332
# Computing power spectra 333
# Computing power spectra 334
# Computing power spectra 335
# Computing power spectra 336
# Computing power spectra 337
# Computing power spectra 338
# Computing power spectra 339
# Computing power spectra 340
# Computing power spectra 341
# Computing power spectra 342
# Computing power spectra 343
# Computing power spectra 344
# Computing power spectra 345
# Computing power spectra 346
# Computing power spectra 347
# Computing power spectra 348
# Computing power spectra 349
# Computing power spectra 350
# Computing power spectra 351
# Computing power spectra 352
# Computing power spectra 353
# Computing power spectra 354
# Computing power spectra 355
# Computing power spectra 356
# Computing power spectra 357
# Computing power spectra 358
# Computing power spectra 359
# Computing power spectra 360
# Computing power spectra 361
# Computing power spectra 362
# Computing power spectra 363
# Computing power spectra 364
# Computing power spectra 365
# Computing power spectra 366
# Computing power spectra 367
# Computing power spectra 368
# Computing power spectra 369
# Computing power spectra 370
# Computing power spectra 371
# Computing power spectra 372
# Computing power spectra 373
# Computing power spectra 374
# Computing power spectra 375
# Computing power spectra 376
# Computing power spectra 377
# Computing power spectra 378
# Computing power spectra 379
# Computing power spectra 380
# Computing power spectra 381
# Computing power spectra 382
# Computing power spectra 383
# Computing power spectra 384
# Computing power spectra 385
# Computing power spectra 386
# Computing power spectra 387
# Computing power spectra 388
# Computing power spectra 389
# Computing power spectra 390
# Computing power spectra 391
# Computing power spectra 392
# Computing power spectra 393
# Computing power spectra 394
# Computing power spectra 395
# Computing power spectra 396
# Computing power spectra 397
# Computing power spectra 398
# Computing power spectra 399
# Computing power spectra 400
# Computing power spectra 401
# Computing power spectra 402
# Computing power spectra 403
# Computing power spectra 404
# Computing power spectra 405
# Computing power spectra 406
# Computing power spectra 407
# Computing power spectra 408
# Computing power spectra 409
# Computing power spectra 410
# Computing power spectra 411
# Computing power spectra 412
# Computing power spectra 413
# Computing power spectra 414
# Computing power spectra 415
# Computing power spectra 416
# Computing power spectra 417
# Computing power spectra 418
# Computing power spectra 419
# Computing power spectra 420
# Computing power spectra 421
# Computing power spectra 422
# Computing power spectra 423
# Computing power spectra 424
# Computing power spectra 425
# Computing power spectra 426
# Computing power spectra 427
# Computing power spectra 428
# Computing power spectra 429
# Computing power spectra 430
# Computing power spectra 431
# Computing power spectra 432
# Computing power spectra 433
# Computing power spectra 434
# Computing power spectra 435
# Computing power spectra 436
# Computing power spectra 437
# Computing power spectra 438
# Computing power spectra 439
# Computing power spectra 440
# Computing power spectra 441
# Computing power spectra 442
# Computing power spectra 443
# Computing power spectra 444
# Computing power spectra 445
# Computing power spectra 446
# Computing power spectra 447
# Computing power spectra 448
# Computing power spectra 449
# Computing power spectra 450
# Computing power spectra 451
# Computing power spectra 452
# Computing power spectra 453
# Computing power spectra 454
# Computing power spectra 455
# Computing power spectra 456
# Computing power spectra 457
# Computing power spectra 458
# Computing power spectra 459
# Computing power spectra 460
# Computing power spectra 461
# Computing power spectra 462
# Computing power spectra 463
# Computing power spectra 464
# Computing power spectra 465
# Computing power spectra 466
# Computing power spectra 467
# Computing power spectra 468
# Computing power spectra 469
# Computing power spectra 470
# Computing power spectra 471
# Computing power spectra 472
# Computing power spectra 473
# Computing power spectra 474
# Computing power spectra 475
# Computing power spectra 476
# Computing power spectra 477
# Computing power spectra 478
# Computing power spectra 479
# Computing power spectra 480
# Computing power spectra 481
# Computing power spectra 482
# Computing power spectra 483
# Computing power spectra 484
# Computing power spectra 485
# Computing power spectra 486
# Computing power spectra 487
# Computing power spectra 488
# Computing power spectra 489
# Computing power spectra 490
# Computing power spectra 491
# Computing power spectra 492
# Computing power spectra 493
# Computing power spectra 494
# Computing power spectra 495
# Computing power spectra 496
# Computing power spectra 497
# Computing power spectra 498
# Computing power spectra 499
# Computing power spectra 500
# Computing power spectra 501
# Computing power spectra 502
# Computing power spectra 503
# Computing power spectra 504
# Computing power spectra 505
# Computing power spectra 506
# Computing power spectra 507
# Computing power spectra 508
# Computing power spectra 509
# Computing power spectra 510
# Computing power spectra 511
# Computing power spectra 512

# %%
*_,c_bin= (bin_spectra(np.real(c_l_hat), nside, delta_ell))

# %%
c_hat=np.zeros((n_bins, nfreqs, nfreqs)) #clip any eigenvalues that are negative and put to zerp
for b in range(n_bins):
    
    cov = 0.5 * (c_bin[b] + c_bin[b].T) #symmetric or Hermitian?

    # Eigen-decomposition (since it's symmetric, use eigh)
    eigvals, eigvecs = np.linalg.eigh(cov)

    # Zero out negative eigenvalues
    eigvals_clipped = np.clip(eigvals, a_min=0, a_max=None)
    
    epsilon=1e-10

    # Reconstruct the covariance matrix
    c_hat[b] = (eigvecs @ np.diag(eigvals_clipped) @ eigvecs.T)#+ epsilon*np.identity(nfreqs)

# %%
# np.save('binned_empirical.npy', c_hat)

# %%
np.all(eigvals_clipped >= 0)
# Out:
# np.True_

# %%
def is_psd(P, tol=1e-15):
    eigenvalues = np.linalg.eigvalsh(P)  # symmetric-optimized
    return np.all(eigenvalues >= -tol) 
print("Is model PSD?", is_psd(c_hat))
# Out:
# Is model PSD? False

# %%
def pca(empirical, r):
    """
    Perform PCA on the covariance matrix.
    
    Parameters:
    ----------
    c_hat : np.ndarray
        Covariance matrix of shape (n_bins, n_freq, n_freq).
    
    r : int
        Number of principal components to retain.
    
    Returns:
    -------
    F : np.ndarray
        Matrix of shape (n_freq, r) containing the principal components.
    
    P_b : np.ndarray
        Matrix of shape (n_bins, r, r) containing the eigenvalues and eigenvectors.
    """
    # Perform PCA
    R_global = np.mean(empirical, axis=0)  # c_hat has shape (n_bins, n_freqs, n_freqs)
    #eigen decompositiom
    eigvals, eigvecs = np.linalg.eigh(R_global) #ascending order
    #Take the top r eigenvectors:
    F_i = eigvecs[:, -r:]  # largest eigenvectors
    epsilon=1e-6

    P_b = np.zeros((n_bins, r, r))
    for b in range(n_bins):
        P_b[b] =np.dot( F_i.T , np.dot(empirical[b] , F_i)) #projecting the empirical covariance into the subspace spanned by F.
        P_b[b] = 0.5 * (P_b[b] + P_b[b].T) + epsilon * np.eye(r)
    return eigvals,F_i, P_b*500

# %%
def guess_params(nfreqs,n_bins, r):
    
    #Initial guess for F
    F_i= np.zeros((nfreqs, r))# N_channels x r
    # F_i= np.random.randn(nfreqs, r)

    # initial guess for P_l for each bin
    P_l=np.zeros((n_bins, r,r))
    for bin in range(n_bins):
        A = np.random.randn(r, r)
        #P_l[bin,:,:]= np.identity(r) #r x r #symmetric
        P_l[bin,:,:]=np.dot(A , A.T) + 1e-2 * np.eye(r) #strictly positive definite + symmetric
    return F_i, P_l

# %%
_,F_pca, P_b_pca = pca(c_hat,r)
# F_pca, P_b_pca = guess_params(nfreqs, n_bins,r)
print(F_pca.shape)
print(P_b_pca.shape)
params_pca = np.concatenate([F_pca.flatten(), P_b_pca.flatten()])
# print(params_pca.shape)

# # Check recovery
# F_re = params_pca[:nfreqs * r].reshape((nfreqs, r))
# P_b_re = params_pca[nfreqs * r:].reshape((n_bins, r, r))
# print(F_re.shape)
# print(P_b_re.shape)
# print(F_re.size)
# print(P_b_re.size)

# np.allclose(F_pca, F_re)  # should return True
# np.allclose(P_b_pca, P_b_re)  # should return True
# Out:
# (181, 3)
# (51, 3, 3)

# %%
def model_covariance(F, P_b, C_noise, n_bins):
    
    # F: (N_channels, r), P_b: (r, r), C_HI & C_noise: (N_channels, N_channels)
    C_b= np.zeros((n_bins, nfreqs, nfreqs))
    for b in range(n_bins):
        C_b[b,:,:]= C_noise[b,:,:] + np.dot(F,np.dot(P_b[b,:,:], F.T))
    return C_b

# %%
c_model= model_covariance(F_pca, P_b_pca,noise_binned, n_bins)

# %%
plt.plot(c_hat[:,10,10], label='c_hat')
plt.plot(c_model[:,10,10], label='c_model')
plt.plot(fgds_binned[:,10,10], label='fgds_binned')
plt.plot(noise_binned[:,10,10], label='noise_binned')
# plt.plot(noise_binned[:,0,0] + fgds_binned[:,0,0], label='noise + fgds binned')
plt.yscale('log')
plt.legend()

# %%
def is_psd(P, tol=0):
    eigenvalues = np.linalg.eigvalsh(P)  # symmetric-optimized
    return np.all(eigenvalues >= tol)  
print("Is model PSD?", is_psd(c_model))
# Out:
# Is model PSD? True

# %%
def smica(params, noise,empirical,  n_bins, nfreqs, r):
    
    # Reshape the flattened params back into F_init and P_b_init
    
    F_i = params[:nfreqs * r].reshape((nfreqs, r))
    P_b = params[nfreqs * r:].reshape((n_bins,r,r))
    
    
    """# === Normalize columns of F and rescale P accordingly ===
    for i in range(r):
        norm = np.linalg.norm(F[:, i])

        F[:, i] /= norm  # normalize column
        for b in range(n_bins):
            P_b[b, i, :] *= norm
            P_b[b, :, i] *= norm  # symmetric scaling"""
    
    
    # norm = np.linalg.norm(F, axis=0)
    
    # # Normalize F
    # F_normalized = F / norm        
    # # Adjust P_b: D^{-1} P_b D^{-1}
    # D_inv = np.diag(1.0 / norm)
    # for b in range(n_bins):
    #     P_b[b] = D_inv @ P_b[b] @ D_inv
                
    # === Compute the cost function ===            
    cost=0
    # model=np.zeros((n_bins, nfreqs, nfreqs))
    # model_inv=np.zeros((n_bins, nfreqs, nfreqs))
    
    # term=np.zeros(n_bins)
    for b in range(n_bins):
        model=  noise[b] + np.dot(F_i, np.dot(P_b[b], F_i.T))
        model_inv= np.linalg.inv(model)
        
        sign, logdet= np.linalg.slogdet(np.dot(empirical[b],model_inv))
        trace=np.trace(np.dot(empirical[b] , model_inv))
        
        term = -logdet + trace-nfreqs
        cost += term
        
    return cost

# %%
smica(params_pca, noise_binned, c_hat, n_bins, nfreqs, r)
# Out:
# np.float64(2312.898015435229)

# %%
def norm_constraints(params, nfreqs, r, n_bins):
    F_i= params[:nfreqs * r].reshape((nfreqs, r))
    norm=np.zeros(r)
    for j in range(r):
        norm[j]=np.linalg.norm(F_i[:,j])
    return norm

# %%
from scipy.optimize import NonlinearConstraint

constraint = NonlinearConstraint(
    lambda params_pca: norm_constraints(params_pca, nfreqs, r, n_bins),
    lb=np.ones(r),  # lower bounds = 1
    ub=np.ones(r)   # upper bounds = 1 → equality constraint
)

# %%
np.linalg.norm(F_pca[:, 1])
# Out:
# np.float64(1.0000000000000002)

# %%
def jacobian_2(params, noise,  empirical, n_bins, nfreqs, r):
    
    delta_ell=10
    # Reshape the flattened params back into F_init and P_b_init
    F = params[:nfreqs * r].reshape((nfreqs, r))
    P_b = params[nfreqs * r:].reshape((n_bins,r,r))
    
    """# === Normalize columns of F and rescale P accordingly ===
    for i in range(r):
        norm = np.linalg.norm(F[:, i])
        
        F[:, i] /= norm  # normalize column
        for b in range(n_bins):
            # Scale row i and column i of P_b[b] accordingly
            P_b[b, i, :] *= norm
            P_b[b, :, i] *= norm """
            
    # Compute norms of each column of F
    # norm = np.linalg.norm(F, axis=0)
    
    # # Normalize F
    # F_normalized = F / norm        
    # # Adjust P_b: D^{-1} P_b D^{-1}
    # D_inv = np.diag(1.0 / norm)
    # for b in range(n_bins):
    #     P_b[b] = D_inv @ P_b[b] @ D_inv
    
    grad_P=np.zeros_like(P_b) # Derivative wrt P_b
    grad_F=np.zeros_like(F) # Derivative wrt F
    
    for b in range(n_bins):
        
        R= noise[b]+np.dot(F, np.dot(P_b[b], F.T)) # model covariance depending on only unknown parameters
        """try:
            R_inv = np.linalg.inv(R)
        except np.linalg.LinAlgError:
            # Optional: add small regularization to make model invertible
            R += 1e-6 * np.identity(nfreqs)
            R_inv = np.linalg.inv(R)"""
        R_inv= np.linalg.inv(R)
        
        Delta= R_inv - np.dot(R_inv,np.dot(empirical[b], R_inv)) #nf x nf

        # ∂φ/∂P_q 
        grad_P[b,:,:]= np.dot(F.T, np.dot(Delta, F)) # (r,r)
        # ∂φ/∂F
        grad_F += 2*np.dot(Delta, np.dot(F, P_b[b])) # (nf,r)
        
    # Flatten the gradients
    grad_P_flat = grad_P.flatten()
    grad_F_flat = grad_F.flatten()
    # print(grad_F_flat.shape)
    # print(grad_P_flat.shape)
    grad_total= np.concatenate([grad_F_flat.flatten(), grad_P_flat.flatten()])
    return grad_total

# %%
import autograd.numpy as np
from autograd import grad

auto_grad=grad(smica)

# %%
res = optimize.minimize(
    smica,
    x0=params_pca,
    args=( noise_binned,c_hat, n_bins, nfreqs,r),
    method='trust-constr',
    # constraints=constraint,
    jac=jacobian_2,
    options={'disp': True, 'maxiter':100, 'gtol':1e-1, 'xtol':1e-10,'barrier_tol': 1e-6, 'verbose': 2}
)
# Out:
# | niter |f evals|CG iter|  obj func   |tr radius |   opt    |  c viol
# |  28   |  28   |  90   | +1.6278e+03 | 7.58e-06 | 8.15e+02 | 0.00e+00 |
# |  29   |  29   |  91   | +1.6278e+03 | 7.58e-07 | 8.15e+02 | 0.00e+00 |
# |  30   |  30   |  92   | +1.6278e+03 | 7.58e-08 | 8.15e+02 | 0.00e+00 |
# |  31   |  31   |  93   | +1.6278e+03 | 7.58e-09 | 8.15e+02 | 0.00e+00 |
# |  32   |  32   |  94   | +1.6278e+03 | 7.58e-10 | 8.15e+02 | 0.00e+00 |
# |  33   |  33   |  95   | +1.6266e+03 | 5.30e-09 | 8.15e+02 | 0.00e+00 |
# |  34   |  34   |  96   | +1.6266e+03 | 5.30e-10 | 8.15e+02 | 0.00e+00 |
# |  35   |  35   |  97   | +1.6266e+03 | 5.30e-11 | 8.15e+02 | 0.00e+00 |
#
# `xtol` termination condition is satisfied.
# Number of iterations: 35, function evaluations: 35, CG iterations: 97, optimality: 8.15e+02, constraint violation: 0.00e+00, execution time:  9.7 s.

# %%
from pprint import pprint
pprint(res)
# Out:
#           message: `xtol` termination condition is satisfied.
#           success: True
#            status: 2
#               fun: 1626.5896543480173
#                 x: [-3.780e-03  2.004e-03 ...  4.725e-03  1.397e+00]
#               nit: 35
#              nfev: 35
#              njev: 35
#              nhev: 0
#          cg_niter: 97
#      cg_stop_cond: 2
#              grad: [-1.616e+01  8.444e+00 ... -3.881e-02  4.762e-01]
#   lagrangian_grad: [-1.616e+01  8.444e+00 ... -3.881e-02  4.762e-01]
#            constr: []
#               jac: []
#       constr_nfev: []
#       constr_njev: []
#       constr_nhev: []
#                 v: []
#            method: equality_constrained_sqp
#        optimality: 814.8335923336006
#  constr_violation: 0
#    execution_time: 9.737366199493408
#         tr_radius: 5.304745480083034e-11
#    constr_penalty: 1.0
#             niter: 35

# %%
result=res.x
print(result.shape)
P_b_out = result[nfreqs*r:].reshape((n_bins,r,r))
F_out = result[:nfreqs*r].reshape((nfreqs, r))
print(P_b_out.shape)
print(F_out.shape)
C_result=np.zeros_like(c_hat)
for b in range(n_bins):
    
    C_result[b]=np.dot(F_out, np.dot(P_b_out[b], F_out.T))
# Out:
# (1002,)
# (51, 3, 3)
# (181, 3)

# %%
np.all(np.linalg.eigvals(C_result) >=0)
# Out:
# np.True_

# %%
np.all(np.linalg.eigvals(P_b_pca) >=0)
# Out:
# np.True_

# %%
plt.plot(leff,C_result[:,10,10],'k.', label="result covariance")
plt.plot(leff,c_hat[:,10,10], label="empirical covariance")
plt.plot(leff,c_model[:,10,10], label="model covaraince")
# plt.plot(leff, hi_binned[:,10,10], label="hi covaraince")
plt.plot(leff,noise_binned[:,10,10], label="noise covariance")
plt.plot(leff, fgds_binned[:,10,10], label="synch+ff cl")
plt.yscale('log')
plt.legend()

# %%
# plt.plot(leff,(C_result[:,10,10] - c_hat[:,10,10]))
plt.plot(leff,(C_result[:,10,10]/3 - fgds_binned[:,10,10])/fgds_binned[:,10,10])
# plt.ylim(-0.5,0.5)) 
plt.axhline(0, color='r', linestyle='--')
